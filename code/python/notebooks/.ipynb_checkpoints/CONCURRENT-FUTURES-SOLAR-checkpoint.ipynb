# %%
import concurrent.futures
import os,sys
from datetime import datetime, timedelta
from pathlib import Path
import logger
from compute_solar import solar_workflow

# %%
LOG = logger.get_logger(__name__)

# %%
if __name__ == '__main__':
    import traceback
    
    n_procs = os.cpu_count()
    worker_pool = concurrent.futures.ProcessPoolExecutor(max_workers=10)
    
    start_date = '1-2-2022'
    end_date = '5-2-2022'
    
    start_dt = datetime.strptime(start_date, "%d-%m-%Y")
    end_dt = datetime.strptime(end_date, "%d-%m-%Y")
    
    # Generate a list of dates
    date_range = [start_dt + timedelta(days=i) for i in range((end_dt - start_dt).days + 1)]
    futures = {}
    region = 'all'
    
    # Loop over the dates
    for date in date_range: 
        date_s = date.strftime('%Y/%m/%d')
        LOG.info(f'Computing ratio of tilting to clearsky irradiance for {date_s}')
        future = worker_pool.submit(solar_workflow, date_s, region) 
        futures[future] = f"The job for {date}"

    for future, desc in futures.items():
        try:
            result = future.result()
            LOG.info(f"{desc} completed successfully")
        except Exception as e:
            LOG.error(f"{desc} failed with error:\n{traceback.format_exc()}")
# Out:
# 2025-04-07 20:04:59,424:__main__:INFO: Computing ratio of tilting to clearsky irradiance for 2022/02/01
# 2025-04-07 20:04:59,483:__main__:INFO: Computing ratio of tilting to clearsky irradiance for 2022/02/02
# 2025-04-07 20:04:59,489:__main__:INFO: Computing ratio of tilting to clearsky irradiance for 2022/02/03
# 2025-04-07 20:04:59,490:__main__:INFO: Computing ratio of tilting to clearsky irradiance for 2022/02/04
# 2025-04-07 20:04:59,488:compute_solar:INFO: reading data for 2022/02/01
# 2025-04-07 20:04:59,491:__main__:INFO: Computing ratio of tilting to clearsky irradiance for 2022/02/05
# 2025-04-07 20:04:59,491:compute_solar:INFO: getting region shape for: all
# 2025-04-07 20:04:59,490:compute_solar:INFO: reading data for 2022/02/02
# 2025-04-07 20:04:59,491:compute_solar:INFO: reading data for 2022/02/03
# 2025-04-07 20:04:59,492:compute_solar:INFO: reading data for 2022/02/04
# 2025-04-07 20:04:59,496:compute_solar:INFO: getting region shape for: all
# 2025-04-07 20:04:59,494:compute_solar:INFO: reading data for 2022/02/05
# 2025-04-07 20:04:59,497:compute_solar:INFO: getting region shape for: all
# 2025-04-07 20:04:59,498:compute_solar:INFO: getting region shape for: all
# 2025-04-07 20:04:59,500:compute_solar:INFO: getting region shape for: all
# 2025-04-07 20:04:59,681:compute_solar:INFO: chunking data with lat/lon size of: NOT CHUNKING
# 2025-04-07 20:04:59,685:compute_solar:INFO: Loading 102 files
# 2025-04-07 20:04:59,702:compute_solar:INFO: chunking data with lat/lon size of: NOT CHUNKING
# 2025-04-07 20:04:59,704:compute_solar:INFO: chunking data with lat/lon size of: NOT CHUNKING
# 2025-04-07 20:04:59,705:compute_solar:INFO: Loading 102 files
# 2025-04-07 20:04:59,705:compute_solar:INFO: chunking data with lat/lon size of: NOT CHUNKING
# 2025-04-07 20:04:59,708:compute_solar:INFO: Loading 102 files
# 2025-04-07 20:04:59,709:compute_solar:INFO: Loading 102 files
# 2025-04-07 20:04:59,734:compute_solar:INFO: chunking data with lat/lon size of: NOT CHUNKING
# 2025-04-07 20:04:59,737:compute_solar:INFO: Loading 102 files
# 2025-04-07 20:05:18,645:compute_solar:INFO: apply mask for region: all
# INFO:compute_solar:apply mask for region: all
# 2025-04-07 20:05:18,676:compute_solar:INFO: apply mask for region: all
# INFO:compute_solar:apply mask for region: all
# 2025-04-07 20:05:18,705:compute_solar:INFO: reading dataset variables
# INFO:compute_solar:reading dataset variables
# 2025-04-07 20:05:18,733:compute_solar:INFO: apply mask for region: all
# 2025-04-07 20:05:18,733:compute_solar:INFO: reading dataset variables
# INFO:compute_solar:reading dataset variables
# INFO:compute_solar:apply mask for region: all
# 2025-04-07 20:05:18,763:compute_solar:INFO: apply mask for region: all
# INFO:compute_solar:apply mask for region: all
# 2025-04-07 20:05:18,791:compute_solar:INFO: reading dataset variables
# INFO:compute_solar:reading dataset variables
# 2025-04-07 20:05:18,804:compute_solar:INFO: apply mask for region: all
# INFO:compute_solar:apply mask for region: all
# 2025-04-07 20:05:18,805:compute_solar:INFO: reading dataset variables
# INFO:compute_solar:reading dataset variables
# 2025-04-07 20:05:18,845:compute_solar:INFO: reading dataset variables
# INFO:compute_solar:reading dataset variables
# 2025-04-07 20:08:02,384:compute_solar:INFO: irradiance read
# INFO:compute_solar:irradiance read
# 2025-04-07 20:08:02,765:compute_solar:INFO: irradiance read
# INFO:compute_solar:irradiance read
# 2025-04-07 20:08:02,795:compute_solar:INFO: mask applied to irradiance
# INFO:compute_solar:mask applied to irradiance
# 2025-04-07 20:08:02,977:compute_solar:INFO: irradiance read
# INFO:compute_solar:irradiance read
# 2025-04-07 20:08:03,187:compute_solar:INFO: mask applied to irradiance
# INFO:compute_solar:mask applied to irradiance
# 2025-04-07 20:08:03,402:compute_solar:INFO: mask applied to irradiance
# INFO:compute_solar:mask applied to irradiance
# 2025-04-07 20:08:03,539:compute_solar:INFO: running pvlib functions
# INFO:compute_solar:running pvlib functions
# 2025-04-07 20:08:03,946:compute_solar:INFO: running pvlib functions
# INFO:compute_solar:running pvlib functions
# 2025-04-07 20:08:04,151:compute_solar:INFO: running pvlib functions
# INFO:compute_solar:running pvlib functions
# 2025-04-07 20:08:04,554:compute_solar:INFO: irradiance read
# INFO:compute_solar:irradiance read
# 2025-04-07 20:08:04,975:compute_solar:INFO: mask applied to irradiance
# INFO:compute_solar:mask applied to irradiance
# 2025-04-07 20:08:05,659:compute_solar:INFO: irradiance read
# INFO:compute_solar:irradiance read
# 2025-04-07 20:08:05,746:compute_solar:INFO: running pvlib functions
# INFO:compute_solar:running pvlib functions
# 2025-04-07 20:08:06,100:compute_solar:INFO: mask applied to irradiance
# INFO:compute_solar:mask applied to irradiance
# 2025-04-07 20:08:06,891:compute_solar:INFO: running pvlib functions
# INFO:compute_solar:running pvlib functions
# 2025-04-07 20:09:49,869:compute_solar:INFO: Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/all/2022/02//all_timeseries_2022-02-04.nc
# INFO:compute_solar:Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/all/2022/02//all_timeseries_2022-02-04.nc
# 2025-04-07 20:09:51,365:compute_solar:INFO: Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/all/2022/02//all_timeseries_2022-02-01.nc
# INFO:compute_solar:Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/all/2022/02//all_timeseries_2022-02-01.nc
# 2025-04-07 20:09:51,468:__main__:INFO: The job for 2022-02-01 00:00:00 completed successfully
# 2025-04-07 20:09:54,493:compute_solar:INFO: Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/all/2022/02//all_timeseries_2022-02-03.nc
# INFO:compute_solar:Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/all/2022/02//all_timeseries_2022-02-03.nc
# 2025-04-07 20:09:55,275:compute_solar:INFO: Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/all/2022/02//all_timeseries_2022-02-05.nc
# INFO:compute_solar:Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/all/2022/02//all_timeseries_2022-02-05.nc
# 2025-04-07 20:09:58,205:compute_solar:INFO: Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/all/2022/02//all_timeseries_2022-02-02.nc
# INFO:compute_solar:Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/all/2022/02//all_timeseries_2022-02-02.nc
# 2025-04-07 20:09:58,440:__main__:INFO: The job for 2022-02-02 00:00:00 completed successfully
# 2025-04-07 20:09:58,441:__main__:INFO: The job for 2022-02-03 00:00:00 completed successfully
# 2025-04-07 20:09:58,442:__main__:INFO: The job for 2022-02-04 00:00:00 completed successfully
# 2025-04-07 20:09:58,442:__main__:INFO: The job for 2022-02-05 00:00:00 completed successfully
