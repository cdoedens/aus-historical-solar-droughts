# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import xarray as xr
from pathlib import Path

from matplotlib.cm import get_cmap
import regionmask

# %%
variables = ['freq', 'amp', 'dur', 'mean']  # , 'num']
seasons = ['summer', 'autumn', 'winter', 'spring']
file_path = Path('/g/data/er8/users/cd3022/solar_drought/regional_metrics/')

# Dictionary to hold each variable's DataArray
var_dict = {}

for var in variables:
    season_data = []
    for season in seasons:
        ds = xr.open_dataset(file_path / f'{var}_{season}.nc')
        da = next(iter(ds.data_vars.values()))
        da = da.expand_dims(season=[season])  # Add season as a coordinate
        season_data.append(da)
    var_dict[var] = xr.concat(season_data, dim='season')

# Combine into one Dataset
ds = xr.Dataset(var_dict)

# %%
data = ds['dur'].sel(season='winter')
land_mask = regionmask.defined_regions.natural_earth_v5_0_0.land_110.mask(data)
data_landonly = data.where(land_mask == 0)

latitudes = ds.latitude
longitudes = ds.longitude

# Create a figure
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()})

mesh=ax.pcolormesh(longitudes, latitudes, data_landonly, cmap='plasma',vmin=0,  transform=ccrs.PlateCarree())

ax.coastlines()
cbar = plt.colorbar(mesh,ax=ax)
# cbar.ax.tick_params(labelsize=5)  # Set the font size for the colorbar ticks
cbar.set_label(f'{var}') 
 
plt.tight_layout()

plt.show()

# %%
fig, ax = plt.subplots(
    nrows=len(variables), ncols=len(seasons),
    figsize=(4 * len(seasons), 3 * len(variables)),
    subplot_kw={'projection': ccrs.PlateCarree()}
)
for i, var in enumerate(variables):
    for j, season in enumerate(seasons):
        data = ds[var].sel(season=season)
        land_mask = regionmask.defined_regions.natural_earth_v5_0_0.land_110.mask(data)
        data_landonly = data.where(land_mask == 0)
        
        latitudes = data.latitude
        longitudes = data.longitude
        
        mesh=ax[i,j].pcolormesh(longitudes, latitudes, data_landonly, cmap='plasma',vmin=0,  transform=ccrs.PlateCarree())
        
        # ax[i,j].coastlines()
        cbar = plt.colorbar(mesh,ax=ax[i,j])

# %%
# Start plotting
fig, axes = plt.subplots(
    nrows=len(variables), ncols=len(seasons),
    figsize=(4 * len(seasons), 3 * len(variables)),
    subplot_kw={'projection': ccrs.PlateCarree()}
)

for i, var in enumerate(variables):
    # Define bin edges for discrete coloring
    da_all = combined.sel(metric=var)
    vmin = float(da_all.min().values)
    vmax = float(da_all.max().values)
    bins = np.linspace(vmin, vmax, 8)  # 7 bins
    cmap = get_cmap('plasma', len(bins) - 1)
    norm = mcolors.BoundaryNorm(bins, ncolors=cmap.N)

    for j, season in enumerate(seasons):
        ax = axes[i, j]
        da_plot = combined.sel(metric=var, season=season).squeeze()

        if i == 0:
            ax.set_title(season, fontsize=12)
        if j == 0:
            ax.set_ylabel(var, fontsize=12)

        mesh = ax.pcolormesh(
            da_plot['longitude'].values,
            da_plot['latitude'].values,
            da_plot.values,
            cmap=cmap, norm=norm, shading='auto',
            transform=ccrs.PlateCarree()
        )
        ax.coastlines()
        ax.add_feature(cfeature.BORDERS, linewidth=0.5)
        ax.set_xticks([])
        ax.set_yticks([])

    # Add shared colorbar for this metric (row)
    cbar_ax = fig.add_axes([
        0.92,                              # left
        0.9 - (i + 1) * 0.17,              # bottom
        0.015,                             # width
        0.14                               # height
    ])
    cbar = fig.colorbar(mesh, cax=cbar_ax, ticks=bins, spacing='proportional')
    cbar.ax.set_yticklabels([f'{b:.2f}' for b in bins])
    cbar.set_label(var)

plt.tight_layout(rect=[0, 0, 0.9, 1])
plt.show()
# Out:
# /jobfs/142467477.gadi-pbs/ipykernel_3102467/74078921.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = get_cmap('plasma', len(bins) - 1)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 26
#      23 if j == 0:
#      24     ax.set_ylabel(var, fontsize=12)
# ---> 26 mesh = ax.pcolormesh(
#      27     da_plot['longitude'].values,
#      28     da_plot['latitude'].values,
#      29     da_plot.values,
#      30     cmap=cmap, norm=norm, shading='auto',
#      31     transform=ccrs.PlateCarree()
#      32 )
#      33 ax.coastlines()
#      34 ax.add_feature(cfeature.BORDERS, linewidth=0.5)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:307, in _add_transform.<locals>.wrapper(self, *args, **kwargs)
#     302     raise ValueError(f'Invalid transform: Spherical {func.__name__} '
#     303                      'is not supported - consider using '
#     304                      'PlateCarree/RotatedPole.')
#     306 kwargs['transform'] = transform
# --> 307 return func(self, *args, **kwargs)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:1768, in GeoAxes.pcolormesh(self, *args, **kwargs)
#    1765 # Add in an argument checker to handle Matplotlib's potential
#    1766 # interpolation when coordinate wraps are involved
#    1767 args, kwargs = self._wrap_args(*args, **kwargs)
# -> 1768 result = super().pcolormesh(*args, **kwargs)
#    1769 # Wrap the quadrilaterals if necessary
#    1770 result = self._wrap_quadmesh(result, **kwargs)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/matplotlib/axes/_axes.py:6428, in Axes.pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6425 shading = shading.lower()
#    6426 kwargs.setdefault('edgecolors', 'none')
# -> 6428 X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
#    6429                                     shading=shading, kwargs=kwargs)
#    6430 coords = np.stack([X, Y], axis=-1)
#    6432 kwargs.setdefault('snap', mpl.rcParams['pcolormesh.snap'])
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5975, in Axes._pcolorargs(self, funcname, shading, *args, **kwargs)
#    5973 if shading == 'flat':
#    5974     if (Nx, Ny) != (ncols + 1, nrows + 1):
# -> 5975         raise TypeError(f"Dimensions of C {C.shape} should"
#    5976                         f" be one smaller than X({Nx}) and Y({Ny})"
#    5977                         f" while using shading='flat'"
#    5978                         f" see help({funcname})")
#    5979 else:    # ['nearest', 'gouraud']:
#    5980     if (Nx, Ny) != (ncols, nrows):
#
# TypeError: Dimensions of C (4, 1726, 2214) should be one smaller than X(2214) and Y(1726) while using shading='flat' see help(pcolormesh)
