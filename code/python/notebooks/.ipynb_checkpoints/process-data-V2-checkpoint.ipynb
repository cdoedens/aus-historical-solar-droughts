# %%
'''
new data collection appears to be working at hourly scale, and with CF algorithm.
now need new script to find droughts from hourly CF data
'''

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path = '/g/data/er8/users/cd3022/solar_drought/hourly_capacity_factors/'
start = '01-01-2020'
end = start
file_name = start + '___' + end + '.nc'
cf_data = xr.open_dataset(file_path+file_name)

# %%
data.values
# Out:
# array([       nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan, 0.00662636, 0.01563461,
#        0.02182888, 0.0320911 , 0.04937805, 0.07377587, 0.10444629,
#        0.14107762, 0.18096372, 0.22348121, 0.26756277, 0.3123133 ,
#        0.35696205, 0.40100563, 0.44404576, 0.48579545, 0.52607603,
#        0.56476109, 0.60179953, 0.63714947, 0.67079815, 0.70273233,
#        0.7329323 , 0.67542838, 0.78823051, 0.82692267, 0.76071825,
#        0.87204303, 0.89178748, 0.82046564, 0.79999243, 0.9391272 ,
#        0.95088618, 0.9606226 , 0.96838965, 0.97419799, 0.97809939,
#        0.8112995 , 0.82678237, 0.97860201, 0.97507498,        nan,
#        0.87130094, 0.9591874 , 0.81217775, 0.67434353, 0.79445735,
#        0.76718632, 0.61104595, 0.8587206 , 0.8352806 , 0.71082283,
#        0.68619109, 0.66005512, 0.58321107, 0.48181711, 0.65901302,
#        0.62405225, 0.43350122, 0.54949559, 0.50994915, 0.4098634 ,
# ...

# %%
cf_data.capacity_factor.sel(latitude=-21.4, longitude = 148.4).plot()

# %%
running_mean = cf_data.rolling(time=6, center=False, min_periods=1).mean()

# %%
running_mean.capacity_factor.sel(latitude=-21.4, longitude = 148.4).plot()
