# %%
from rasterstats import zonal_stats
import rasterio
import pandas as pd
import xarray as xr
import geopandas as gpd
import odc.geo.xr
import os

# %% [markdown]
# # Himawari data

# %%
from pathlib import Path

directory=Path('/g/data/rv74/satellite-products/arc/der/himawari-ahi/solar/p1s/latest/2020/05/05')
file = [f for f in directory.iterdir()][10]

ds = xr.open_dataset(file, chunks={'time': '200MB'}, decode_coords='all')

# %%
ghi = ds.surface_global_irradiance
ghi
# Out:
# <xarray.DataArray 'surface_global_irradiance' (time: 1, latitude: 1726,
#                                                longitude: 2214)> Size: 31MB
# dask.array<open_dataset-surface_global_irradiance, shape=(1, 1726, 2214), dtype=float64, chunksize=(1, 10, 2214), chunktype=numpy.ndarray>
# Coordinates:
#   * time       (time) datetime64[ns] 8B 2020-05-04T23:10:00
#   * latitude   (latitude) float32 7kB -44.5 -44.48 -44.46 ... -10.02 -10.0
#   * longitude  (longitude) float32 9kB 112.0 112.0 112.0 ... 156.2 156.2 156.3
#     crs        int32 4B ...
# Attributes:
#     standard_name:  surface_downwelling_shortwave_flux_in_air
#     long_name:      Total horizontal solar irradiance at surface with bias co...
#     comment:        Bias correction has been applied. Surface downwelling sho...
#     units:          W m-2
#     valid_min:      0
#     valid_max:      140000

# %% [markdown]
# # Convert file to .shx

# %%
# import geopandas as gpd

# boundary_file_path = '/home/548/cd3022/aus-historical-solar-droughts/data/boundary_files/'
# rez_file_name = 'Indicative REZ boundaries 2024 GIS data.kml'
# # Read the KML file (make sure to specify the correct layer name)
# gdf = gpd.read_file(boundary_file_path + rez_file_name, engine='pyogrio')

# # Save as a shapefile
# gdf.to_file(boundary_file_path + "REZ-boundaries.shx")
# Out:
# /jobfs/137640620.gadi-pbs/ipykernel_4128597/183141540.py:9: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf.to_file(boundary_file_path + "REZ-boundaries.shx")
# WARNING:fiona._env:Normalized/laundered field name: 'Description' to 'Descriptio'

# %% [markdown]
# # Create mask with rasterio

# %%
shapefile = '/home/548/cd3022/aus-historical-solar-droughts/data/boundary_files/REZ-boundaries.shx'
gdf = gpd.read_file(shapefile)
gdf.geometry
# Out:
# 0     POLYGON Z ((146.13492 -17.65256 0.00000, 146.0...
# 1     POLYGON Z ((143.72015 -16.97938 0.00000, 143.8...
# 2     POLYGON Z ((146.27782 -18.71920 0.00000, 146.2...
# 3     POLYGON Z ((147.64366 -19.94015 0.00000, 147.6...
# 4     POLYGON Z ((145.82086 -23.84279 0.00000, 145.7...
# 5     POLYGON Z ((149.95860 -24.15382 0.00000, 149.9...
# 6     POLYGON Z ((152.27090 -25.06574 0.00000, 152.2...
# 7     POLYGON Z ((150.85197 -26.29194 0.00000, 151.0...
# 8     POLYGON Z ((149.13813 -23.31492 0.00000, 149.3...
# 9     POLYGON Z ((149.63862 -28.78058 0.00000, 149.7...
# 10    POLYGON Z ((151.15540 -30.83766 0.00000, 151.0...
# 11    POLYGON Z ((148.25364 -32.36623 0.00000, 148.2...
# 12    POLYGON Z ((140.85352 -31.38122 0.00000, 140.9...
# 13    POLYGON Z ((145.39823 -35.26336 0.00000, 145.3...
# 14    POLYGON Z ((147.53640 -34.91654 0.00000, 147.5...
# 15    POLYGON Z ((148.38778 -34.94197 0.00000, 148.4...
# 16    POLYGON Z ((149.29244 -35.92343 0.00000, 149.3...
# 17    POLYGON Z ((151.07816 -32.01056 0.00000, 151.0...
# 18    POLYGON Z ((152.30212 -32.93769 0.00000, 152.6...
# 19    POLYGON Z ((151.20162 -34.59197 0.00000, 151.1...
# 20    POLYGON Z ((150.69397 -34.60326 0.00000, 150.6...
# 21    POLYGON Z ((147.16379 -36.26820 0.00000, 147.3...
# 22    POLYGON Z ((142.37367 -34.49644 0.00000, 142.4...
# 23    POLYGON Z ((142.79744 -36.42791 0.00000, 143.0...
# 24    POLYGON Z ((142.48372 -37.76645 0.00000, 142.7...
# 25    POLYGON Z ((147.52083 -37.79004 0.00000, 147.5...
# 26    POLYGON Z ((146.07302 -36.43814 0.00000, 145.9...
# 27    MULTIPOLYGON Z (((145.87167 -39.95774 0.00000,...
# 28    POLYGON Z ((142.37694 -38.84842 0.00000, 142.0...
# 29    POLYGON Z ((139.54832 -35.14815 0.00000, 139.3...
# 30    POLYGON Z ((139.62534 -33.84098 0.00000, 139.6...
# 31    POLYGON Z ((138.56613 -31.80401 0.00000, 138.5...
# 32    POLYGON Z ((137.47043 -34.18961 0.00000, 137.4...
# 33    POLYGON Z ((137.43837 -33.14963 0.00000, 137.2...
# 34    POLYGON Z ((138.82776 -29.93891 0.00000, 138.9...
# 35    POLYGON Z ((136.18893 -29.83613 0.00000, 136.2...
# 36    POLYGON Z ((135.60472 -34.88957 0.00000, 135.5...
# 37    POLYGON Z ((134.04471 -32.46590 0.00000, 134.0...
# 38    POLYGON Z ((139.88901 -37.84521 0.00000, 139.6...
# 39    POLYGON Z ((147.00163 -40.99056 0.00000, 147.1...
# 40    POLYGON Z ((145.72474 -40.96037 0.00000, 145.7...
# 41    POLYGON Z ((147.62309 -42.44651 0.00000, 147.5...
# 42    POLYGON Z ((147.00433 -40.01414 0.00000, 147.6...
# Name: geometry, dtype: geometry

# %% [markdown]
# ## Check crs is EPSG:4326

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
mask = rasterio.features.geometry_mask(
            gdf.geometry,
            out_shape=ghi.odc.geobox.shape,
            transform=ghi.odc.geobox.affine,
            all_touched=False,
            invert=False)
mask.shape
# Out:
# (1726, 2214)

# %%
mask = xr.DataArray(mask, dims=('latitude', 'longitude'),coords=dict(
        longitude=ghi.longitude,
        latitude=ghi.latitude))

# %%
mask.plot()

# %%
ghi_region = ghi.where(~mask, drop=True)
ghi_region.plot()

# %% [markdown]
# # Apply function to mask

# %%
# first define a new statistic as a function
def new_stat(array):
    """This is meaningless just to prove you can add your own calculation"""
    out = array.min() + array.max()
    return out

# %%
# then we test it on 1 timestep
with rasterio.open(f'netcdf:{file}:surface_global_irradiance') as src:
    affine = src.transform
    array = src.read(1)
    newstats = pd.DataFrame(zonal_stats(shapefile, array, 
        affine=affine, stats='mean', add_stats={'mysum': new_stat}))
newstats
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/rasterstats/io.py:328: NodataWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn(
#             mean   mysum
# 0   50154.996779   71931
# 1   55868.980184   95249
# 2   55515.778037   83251
# 3   49651.796090   63991
# 4   53516.343337   95191
# 5   48726.536987   75709
# 6   56104.202265   72153
# 7   55164.909706  101901
# 8   54783.515695   84802
# 9   50764.496988   93722
# 10  49542.665633   70170
# 11  46151.907268   69390
# 12  39671.605329   79113
# 13  38822.915672   69925
# 14  40128.786431   80672
# 15  43691.281380   74748
# 16  38206.266800   68932
# 17  31085.069312   54154
# 18  31863.487696   52070
# 19  36175.848148   51651
# 20  43851.898876   88636
# 21  39064.705221   60802
# 22  36510.336344   66192
# 23  34147.409590   56614
# 24  32002.597747   59691
# 25  29335.343307   52906
# 26  36820.472919   73957
# 27  27833.327608   51406
# 28  30322.609665   53915
# 29  31429.823830   50277
# 30  34832.368315   69539
# 31  34964.894519   69724
# 32  29927.241239   46075
# 33  34035.400656   61888
# 34  38476.464167   76995
# 35  35137.928623   60585
# 36  26956.786261   40996
# 37  16265.964816   38382
# 38  29681.857307   59617
# 39  17674.042535   44652
# 40  27376.215168   50077
# 41  26321.210056   43529
# 42  20765.664185   44258

# %% [markdown]
# # Using Dask for multiple files

# %%
from dask.distributed import Client
ncpus = os.environ.get('PBS_NCPUS')
c = Client(n_workers=int(ncpus))
c
# Out:
# <Client: 'tcp://127.0.0.1:38789' processes=12 threads=12, memory=46.00 GiB>

# %%
files = list(directory.glob("*.nc"))

ds = xr.open_mfdataset(files, parallel=True, chunks={'time': '200MB'})
ghi = ds.surface_global_irradiance
ghi
# Out:
# <xarray.DataArray 'surface_global_irradiance' (time: 103, latitude: 1726,
#                                                longitude: 2214)> Size: 3GB
# dask.array<concatenate, shape=(103, 1726, 2214), dtype=float64, chunksize=(1, 10, 2214), chunktype=numpy.ndarray>
# Coordinates:
#   * time       (time) datetime64[ns] 824B 2020-05-04T18:30:00 ... 2020-05-05T...
#   * latitude   (latitude) float32 7kB -44.5 -44.48 -44.46 ... -10.02 -10.0
#   * longitude  (longitude) float32 9kB 112.0 112.0 112.0 ... 156.2 156.2 156.3
# Attributes:
#     standard_name:  surface_downwelling_shortwave_flux_in_air
#     long_name:      Total horizontal solar irradiance at surface with bias co...
#     comment:        Bias correction has been applied. Surface downwelling sho...
#     units:          W m-2
#     valid_min:      0
#     valid_max:      140000
#     grid_mapping:   crs

# %% [markdown]
# This can be slow, so pre-selecting smaller area can be more efficient

# %% [markdown]
# Get region boundaries from shapefile

# %%
lon_min, lat_min, lon_max, lat_max = gdf.total_bounds
gdf.total_bounds
# Out:
# array([134.039433, -42.574661, 153.128697, -14.24745 ])

# %% [markdown]
# Define a function to select a region based on boundaries

# %%
def select_region(ds):
    ds = ds.sel(latitude=slice(-38, -24), longitude=slice(148, 154))
    return ds
# Out:
# CPU times: user 43 μs, sys: 52 μs, total: 95 μs
# Wall time: 108 μs

# %% [markdown]
# Open file using preprocess to select region of interest

# %%
# %%time
ds = xr.open_mfdataset(files, parallel=True, preprocess=select_region)
ghi = ds.surface_global_irradiance.chunk({'time': '200MB'})
ghi
# Out:
# CPU times: user 2.03 s, sys: 375 ms, total: 2.41 s
# Wall time: 3.24 s
# <xarray.DataArray 'surface_global_irradiance' (time: 103, latitude: 701,
#                                                longitude: 301)> Size: 174MB
# dask.array<rechunk-merge, shape=(103, 701, 301), dtype=float64, chunksize=(103, 10, 301), chunktype=numpy.ndarray>
# Coordinates:
#   * time       (time) datetime64[ns] 824B 2020-05-04T18:30:00 ... 2020-05-05T...
#   * latitude   (latitude) float32 3kB -38.0 -37.98 -37.96 ... -24.02 -24.0
#   * longitude  (longitude) float32 1kB 148.0 148.0 148.0 ... 154.0 154.0 154.0
# Attributes:
#     standard_name:  surface_downwelling_shortwave_flux_in_air
#     long_name:      Total horizontal solar irradiance at surface with bias co...
#     comment:        Bias correction has been applied. Surface downwelling sho...
#     units:          W m-2
#     valid_min:      0
#     valid_max:      140000
#     grid_mapping:   crs
