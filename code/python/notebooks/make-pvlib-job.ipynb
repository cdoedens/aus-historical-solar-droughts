# %% [markdown]
# Regions:
# - REZ
#   - First letter for all of state (e.g. 'Q') or letter/number for specifici REZ (e.g. 'Q2')
#   - REZs with no solar have been removed
# - GCCSA
#   - 1GSYD
#   - 2GMEL
#   - 3GBRI
#   - 4GADE
#   - 5GPER
#   - 6GHOB
#   - 7GDAR
#   - 8ACTE
#
# Tilt:
# - fixed
# - single_axis
#
# Five args must be submitted for the script to run:
# - Start date
# - End date
# - Region
# - Tilt
#
# The job will produce datasets with actual and ideal data

# %%
# from datetime import datetime, timedelta
# from dateutil.relativedelta import relativedelta

# # All himawari data
# first = '1-8-2015'
# num_batches = 12 * 9 + 6

# first_dt = datetime.strptime(first, "%d-%m-%Y")
# dates = []
# for x in range(num_batches):
#     start_dt = first_dt + relativedelta(months =  x)
#     start_date = start_dt.strftime("%d-%m-%Y")
#     end_dt = start_dt + relativedelta(months = 1) - relativedelta(days=1)
#     end_date = end_dt.strftime("%d-%m-%Y")
#     dates.append((start_date, end_date))

# %%
import subprocess
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

script_to_run = 'solar_workflow_runner'

region = 'REZ_S8'
tilt = 'single_axis'

# First full month of data (Aug '15) to latest (Jan '25)
first = '1-8-2015'
num_batches = 12 * 9 + 6

first_dt = datetime.strptime(first, "%d-%m-%Y")
dates = []
for x in range(num_batches):
    start_dt = first_dt + relativedelta(months =  x)
    start_date = start_dt.strftime("%d-%m-%Y")
    end_dt = start_dt + relativedelta(months = 1) - relativedelta(days=1)
    end_date = end_dt.strftime("%d-%m-%Y")
    dates.append((start_date, end_date))

if region[1].upper() == 'ALL':
    ncpus = 13
else:
    ncpus = 48
for start, end in dates:
    
    # Generate a unique file name based on iteration
    joboutdir = '/home/548/cd3022/aus-historical-solar-droughts/code/qsub/'
    job_script_filename = joboutdir + f'{script_to_run}___' + start + '.qsub'
    
    # Open the file for writing
    with open(job_script_filename, "w") as f3:
        f3.write('#!/bin/bash \n')
        f3.write('#PBS -l walltime=1:00:00 \n')
        f3.write('#PBS -l mem=96GB \n')
        f3.write('#PBS -l ncpus=24 \n')
        f3.write('#PBS -l jobfs=10GB \n')
        f3.write('#PBS -l storage=gdata/hh5+gdata/er8+scratch/er8+gdata/rv74+gdata/rt52+gdata/ob53 \n')
        f3.write('#PBS -l other=hyperthread \n')
        f3.write('#PBS -q normal \n')
        f3.write('#PBS -P er8 \n')
        f3.write(f'#PBS -o /home/548/cd3022/aus-historical-solar-droughts/logs/{script_to_run}_{region}_{start}.oe \n')
        f3.write('#PBS -j oe \n')
        f3.write('module use /g/data3/hh5/public/modules \n')
        f3.write('module load conda/analysis3 \n')
        f3.write('conda \n')
        f3.write(f'python3 /home/548/cd3022/aus-historical-solar-droughts/code/python/scripts/{script_to_run}.py {start} {end} {region} {tilt}\n')


    # Submit the generated script to the job scheduler (PBS) using qsub
    try:
        # Run the qsub command and submit the script
        subprocess.run(['qsub', job_script_filename], check=True)
        print(f"Job script {job_script_filename} submitted successfully.")
    except subprocess.CalledProcessError as e:
        print(f"Error submitting job script {job_script_filename}: {e}")
# Out:
# 144403138.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-08-2015.qsub submitted successfully.
# 144403139.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-09-2015.qsub submitted successfully.
# 144403140.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-10-2015.qsub submitted successfully.
# 144403141.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-11-2015.qsub submitted successfully.
# 144403142.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-12-2015.qsub submitted successfully.
# 144403143.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-01-2016.qsub submitted successfully.
# 144403144.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-02-2016.qsub submitted successfully.
# 144403145.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-03-2016.qsub submitted successfully.
# 144403146.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-04-2016.qsub submitted successfully.
# 144403147.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-05-2016.qsub submitted successfully.
# 144403148.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-06-2016.qsub submitted successfully.
# 144403149.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-07-2016.qsub submitted successfully.
# 144403150.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-08-2016.qsub submitted successfully.
# 144403151.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-09-2016.qsub submitted successfully.
# 144403152.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-10-2016.qsub submitted successfully.
# 144403153.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-11-2016.qsub submitted successfully.
# 144403154.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-12-2016.qsub submitted successfully.
# 144403155.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-01-2017.qsub submitted successfully.
# 144403156.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-02-2017.qsub submitted successfully.
# 144403157.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-03-2017.qsub submitted successfully.
# 144403158.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-04-2017.qsub submitted successfully.
# 144403159.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-05-2017.qsub submitted successfully.
# 144403160.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-06-2017.qsub submitted successfully.
# 144403161.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-07-2017.qsub submitted successfully.
# 144403162.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-08-2017.qsub submitted successfully.
# 144403163.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-09-2017.qsub submitted successfully.
# 144403164.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-10-2017.qsub submitted successfully.
# 144403165.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-11-2017.qsub submitted successfully.
# 144403166.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-12-2017.qsub submitted successfully.
# 144403167.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-01-2018.qsub submitted successfully.
# 144403168.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-02-2018.qsub submitted successfully.
# 144403169.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-03-2018.qsub submitted successfully.
# 144403170.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-04-2018.qsub submitted successfully.
# 144403171.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-05-2018.qsub submitted successfully.
# 144403172.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-06-2018.qsub submitted successfully.
# 144403173.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-07-2018.qsub submitted successfully.
# 144403174.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-08-2018.qsub submitted successfully.
# 144403176.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-09-2018.qsub submitted successfully.
# 144403177.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-10-2018.qsub submitted successfully.
# 144403178.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-11-2018.qsub submitted successfully.
# 144403181.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-12-2018.qsub submitted successfully.
# 144403182.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-01-2019.qsub submitted successfully.
# 144403183.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-02-2019.qsub submitted successfully.
# 144403184.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-03-2019.qsub submitted successfully.
# 144403185.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-04-2019.qsub submitted successfully.
# 144403186.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-05-2019.qsub submitted successfully.
# 144403187.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-06-2019.qsub submitted successfully.
# 144403188.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-07-2019.qsub submitted successfully.
# 144403189.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-08-2019.qsub submitted successfully.
# 144403190.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-09-2019.qsub submitted successfully.
# 144403191.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-10-2019.qsub submitted successfully.
# 144403192.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-11-2019.qsub submitted successfully.
# 144403193.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-12-2019.qsub submitted successfully.
# 144403194.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-01-2020.qsub submitted successfully.
# 144403195.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-02-2020.qsub submitted successfully.
# 144403196.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-03-2020.qsub submitted successfully.
# 144403197.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-04-2020.qsub submitted successfully.
# 144403198.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-05-2020.qsub submitted successfully.
# 144403199.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-06-2020.qsub submitted successfully.
# 144403200.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-07-2020.qsub submitted successfully.
# 144403201.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-08-2020.qsub submitted successfully.
# 144403202.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-09-2020.qsub submitted successfully.
# 144403203.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-10-2020.qsub submitted successfully.
# 144403204.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-11-2020.qsub submitted successfully.
# 144403205.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-12-2020.qsub submitted successfully.
# 144403206.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-01-2021.qsub submitted successfully.
# 144403207.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-02-2021.qsub submitted successfully.
# 144403209.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-03-2021.qsub submitted successfully.
# 144403210.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-04-2021.qsub submitted successfully.
# 144403211.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-05-2021.qsub submitted successfully.
# 144403213.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-06-2021.qsub submitted successfully.
# 144403214.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-07-2021.qsub submitted successfully.
# 144403215.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-08-2021.qsub submitted successfully.
# 144403216.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-09-2021.qsub submitted successfully.
# 144403217.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-10-2021.qsub submitted successfully.
# 144403218.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-11-2021.qsub submitted successfully.
# 144403219.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-12-2021.qsub submitted successfully.
# 144403220.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-01-2022.qsub submitted successfully.
# 144403221.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-02-2022.qsub submitted successfully.
# 144403222.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-03-2022.qsub submitted successfully.
# 144403224.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-04-2022.qsub submitted successfully.
# 144403225.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-05-2022.qsub submitted successfully.
# 144403226.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-06-2022.qsub submitted successfully.
# 144403227.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-07-2022.qsub submitted successfully.
# 144403228.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-08-2022.qsub submitted successfully.
# 144403229.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-09-2022.qsub submitted successfully.
# 144403230.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-10-2022.qsub submitted successfully.
# 144403231.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-11-2022.qsub submitted successfully.
# 144403232.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-12-2022.qsub submitted successfully.
# 144403233.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-01-2023.qsub submitted successfully.
# 144403234.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-02-2023.qsub submitted successfully.
# 144403235.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-03-2023.qsub submitted successfully.
# 144403236.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-04-2023.qsub submitted successfully.
# 144403237.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-05-2023.qsub submitted successfully.
# 144403238.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-06-2023.qsub submitted successfully.
# 144403239.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-07-2023.qsub submitted successfully.
# 144403240.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-08-2023.qsub submitted successfully.
# 144403241.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-09-2023.qsub submitted successfully.
# 144403242.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-10-2023.qsub submitted successfully.
# 144403243.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-11-2023.qsub submitted successfully.
# 144403244.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-12-2023.qsub submitted successfully.
# 144403245.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-01-2024.qsub submitted successfully.
# 144403246.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-02-2024.qsub submitted successfully.
# 144403247.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-03-2024.qsub submitted successfully.
# 144403248.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-04-2024.qsub submitted successfully.
# 144403250.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-05-2024.qsub submitted successfully.
# 144403251.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-06-2024.qsub submitted successfully.
# 144403252.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-07-2024.qsub submitted successfully.
# 144403253.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-08-2024.qsub submitted successfully.
# 144403254.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-09-2024.qsub submitted successfully.
# 144403255.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-10-2024.qsub submitted successfully.
# 144403256.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-11-2024.qsub submitted successfully.
# 144403257.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-12-2024.qsub submitted successfully.
# 144403260.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/solar_workflow_runner___01-01-2025.qsub submitted successfully.
