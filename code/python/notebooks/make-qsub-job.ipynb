# %% [markdown]
# Regions:
# - REZ
#   - V
#   - N
#   - S
#   - T
#   - Q
# - GCCSA
#   - 1GSYD
#   - 2GMEL
#   - 3GBRI
#   - 4GADE
#   - 5GPER
#   - 6GHOB
#   - 7GDAR
#   - 8ACTE
#
# Variables:
# - clear_sky_index
# - capacity_factor
# Tilt:
# - fixed
# - single_axis
#
# Five args must be submitted for the script to run:
# - Start date
# - End date
# - Region
# - Variable
# - Tile

# %%
import subprocess
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

script_to_run = 'CONCURRENT-FUTURES-SOLAR'

region = 'GCCSA_2GMEL'
var = 'clear_sky_index'
tilt = 'fixed'
first = '1-1-2016'
months_per_batch = 1
num_batches = 12 * 9

first_dt = datetime.strptime(first, "%d-%m-%Y")
dates = []
for x in range(num_batches):
    start_dt = first_dt + relativedelta(months = months_per_batch * x)
    start_date = start_dt.strftime("%d-%m-%Y")
    end_dt = start_dt + relativedelta(months = months_per_batch) - relativedelta(days=1)
    end_date = end_dt.strftime("%d-%m-%Y")
    dates.append((start_date, end_date))

if region[1].upper() == 'ALL':
    ncpus = 13
else:
    ncpus = 48
for start, end in dates:
    
    # Generate a unique file name based on iteration
    joboutdir = '/home/548/cd3022/aus-historical-solar-droughts/code/qsub/'
    job_script_filename = joboutdir + f'{script_to_run}___' + start + '.qsub'
    
    # Open the file for writing
    with open(job_script_filename, "w") as f3:
        f3.write('#!/bin/bash \n')
        f3.write('#PBS -l walltime=1:00:00 \n')
        f3.write('#PBS -l mem=192GB \n')
        f3.write(f'#PBS -l ncpus={ncpus} \n')
        f3.write('#PBS -l jobfs=10GB \n')
        f3.write('#PBS -l storage=gdata/hh5+gdata/er8+scratch/er8+gdata/rv74+gdata/rt52 \n')
        f3.write('#PBS -l other=hyperthread \n')
        f3.write('#PBS -q normal \n')
        f3.write('#PBS -P er8 \n')
        f3.write(f'#PBS -o /home/548/cd3022/aus-historical-solar-droughts/logs/{script_to_run}_{var}_{region}_{start}.oe \n')
        f3.write('#PBS -j oe \n')
        f3.write('module use /g/data3/hh5/public/modules \n')
        f3.write('module load conda/analysis3 \n')
        f3.write('conda \n')
        f3.write(f'python3 /home/548/cd3022/aus-historical-solar-droughts/code/python/scripts/{script_to_run}.py {start} {end} {region} {var} {tilt}\n')


    # Submit the generated script to the job scheduler (PBS) using qsub
    try:
        # Run the qsub command and submit the script
        subprocess.run(['qsub', job_script_filename], check=True)
        print(f"Job script {job_script_filename} submitted successfully.")
    except subprocess.CalledProcessError as e:
        print(f"Error submitting job script {job_script_filename}: {e}")
# Out:
# 141716298.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2016.qsub submitted successfully.
# 141716299.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2016.qsub submitted successfully.
# 141716300.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2016.qsub submitted successfully.
# 141716301.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2016.qsub submitted successfully.
# 141716302.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2016.qsub submitted successfully.
# 141716303.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2016.qsub submitted successfully.
# 141716304.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2016.qsub submitted successfully.
# 141716305.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2016.qsub submitted successfully.
# 141716306.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2016.qsub submitted successfully.
# 141716307.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2016.qsub submitted successfully.
# 141716309.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2016.qsub submitted successfully.
# 141716310.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2016.qsub submitted successfully.
# 141716311.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2017.qsub submitted successfully.
# 141716312.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2017.qsub submitted successfully.
# 141716313.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2017.qsub submitted successfully.
# 141716314.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2017.qsub submitted successfully.
# 141716315.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2017.qsub submitted successfully.
# 141716316.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2017.qsub submitted successfully.
# 141716317.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2017.qsub submitted successfully.
# 141716318.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2017.qsub submitted successfully.
# 141716320.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2017.qsub submitted successfully.
# 141716321.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2017.qsub submitted successfully.
# 141716322.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2017.qsub submitted successfully.
# 141716323.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2017.qsub submitted successfully.
# 141716324.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2018.qsub submitted successfully.
# 141716325.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2018.qsub submitted successfully.
# 141716326.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2018.qsub submitted successfully.
# 141716327.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2018.qsub submitted successfully.
# 141716328.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2018.qsub submitted successfully.
# 141716329.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2018.qsub submitted successfully.
# 141716330.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2018.qsub submitted successfully.
# 141716331.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2018.qsub submitted successfully.
# 141716332.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2018.qsub submitted successfully.
# 141716333.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2018.qsub submitted successfully.
# 141716334.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2018.qsub submitted successfully.
# 141716335.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2018.qsub submitted successfully.
# 141716336.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2019.qsub submitted successfully.
# 141716337.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2019.qsub submitted successfully.
# 141716338.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2019.qsub submitted successfully.
# 141716339.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2019.qsub submitted successfully.
# 141716340.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2019.qsub submitted successfully.
# 141716341.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2019.qsub submitted successfully.
# 141716342.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2019.qsub submitted successfully.
# 141716343.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2019.qsub submitted successfully.
# 141716344.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2019.qsub submitted successfully.
# 141716345.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2019.qsub submitted successfully.
# 141716346.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2019.qsub submitted successfully.
# 141716347.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2019.qsub submitted successfully.
# 141716348.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2020.qsub submitted successfully.
# 141716349.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2020.qsub submitted successfully.
# 141716350.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2020.qsub submitted successfully.
# 141716351.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2020.qsub submitted successfully.
# 141716352.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2020.qsub submitted successfully.
# 141716353.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2020.qsub submitted successfully.
# 141716354.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2020.qsub submitted successfully.
# 141716355.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2020.qsub submitted successfully.
# 141716356.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2020.qsub submitted successfully.
# 141716357.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2020.qsub submitted successfully.
# 141716358.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2020.qsub submitted successfully.
# 141716359.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2020.qsub submitted successfully.
# 141716360.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2021.qsub submitted successfully.
# 141716361.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2021.qsub submitted successfully.
# 141716363.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2021.qsub submitted successfully.
# 141716365.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2021.qsub submitted successfully.
# 141716366.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2021.qsub submitted successfully.
# 141716367.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2021.qsub submitted successfully.
# 141716368.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2021.qsub submitted successfully.
# 141716369.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2021.qsub submitted successfully.
# 141716370.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2021.qsub submitted successfully.
# 141716371.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2021.qsub submitted successfully.
# 141716372.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2021.qsub submitted successfully.
# 141716373.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2021.qsub submitted successfully.
# 141716375.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2022.qsub submitted successfully.
# 141716376.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2022.qsub submitted successfully.
# 141716377.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2022.qsub submitted successfully.
# 141716378.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2022.qsub submitted successfully.
# 141716379.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2022.qsub submitted successfully.
# 141716380.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2022.qsub submitted successfully.
# 141716381.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2022.qsub submitted successfully.
# 141716382.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2022.qsub submitted successfully.
# 141716383.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2022.qsub submitted successfully.
# 141716384.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2022.qsub submitted successfully.
# 141716385.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2022.qsub submitted successfully.
# 141716386.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2022.qsub submitted successfully.
# 141716387.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2023.qsub submitted successfully.
# 141716388.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2023.qsub submitted successfully.
# 141716389.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2023.qsub submitted successfully.
# 141716391.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2023.qsub submitted successfully.
# 141716392.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2023.qsub submitted successfully.
# 141716393.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2023.qsub submitted successfully.
# 141716394.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2023.qsub submitted successfully.
# 141716395.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2023.qsub submitted successfully.
# 141716396.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2023.qsub submitted successfully.
# 141716397.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2023.qsub submitted successfully.
# 141716398.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2023.qsub submitted successfully.
# 141716399.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2023.qsub submitted successfully.
# 141716401.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-01-2024.qsub submitted successfully.
# 141716403.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-02-2024.qsub submitted successfully.
# 141716404.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-03-2024.qsub submitted successfully.
# 141716405.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-04-2024.qsub submitted successfully.
# 141716406.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-05-2024.qsub submitted successfully.
# 141716408.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-06-2024.qsub submitted successfully.
# 141716409.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-07-2024.qsub submitted successfully.
# 141716410.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-08-2024.qsub submitted successfully.
# 141716411.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-09-2024.qsub submitted successfully.
# 141716412.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-10-2024.qsub submitted successfully.
# 141716413.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-11-2024.qsub submitted successfully.
# 141716414.gadi-pbs
# Job script /home/548/cd3022/aus-historical-solar-droughts/code/qsub/CONCURRENT-FUTURES-SOLAR___01-12-2024.qsub submitted successfully.
