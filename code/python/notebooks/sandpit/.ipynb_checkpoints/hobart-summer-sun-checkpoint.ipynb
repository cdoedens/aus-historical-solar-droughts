# %%
import os
import xarray as xr
import numpy as np
from pathlib import Path
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import logger
import xesmf as xe
from scipy.ndimage import label

import climtas.nci
from dask.distributed import Client, as_completed

# %%
LOG = logger.get_logger(__name__)

# %%
client = Client(
    n_workers=1,
    threads_per_worker=24
)
client
# Out:
# <Client: 'tcp://127.0.0.1:42947' processes=1 threads=24, memory=95.00 GiB>

# %%
def get_hba_data(date):

    date_dt = datetime.strptime(date, "%m-%Y")
    year = date_dt.strftime("%Y")
    month = date_dt.strftime("%m")
    
    ##### Himawari Data
    if date_dt <= datetime.strptime('2019-03-31', '%Y-%m-%d'):
        version = 'v1.0'
    else:
        version = 'v1.1'
    directory=Path(f'/g/data/rv74/satellite-products/arc/der/himawari-ahi/solar/p1s/{version}/{year}/{month}')
    files = sorted(str(p) for p in directory.rglob("*[21-23][0-5][0].nc"))
    files.extend(sorted(str(p) for p in directory.rglob("*00[0-5][0].nc")))
    def _preprocess(ds):
        return ds.surface_global_irradiance.sel(latitude=-42.88, longitude=147.32)
    
    return xr.open_mfdataset(
        files,
        combine='by_coords',
        preprocess=_preprocess,
    )

# %%
data = []

dates = ['12-2022', '01-2023', '02-2023', '12-2023',
        '01-2024', '02-2024', '12-2024', '01-2025']

if __name__ == '__main__':
    futures = {}
    for date in dates:
        future = client.submit(get_hba_data, date)
        futures[future] = f"The job for {date}"
    for future in as_completed(futures):
        result = future.result()
        data.append(result)
ds = xr.concat(data, dim='time')
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/share/proj failed

# %%
ds.load()
# Out:
# 2025-06-14 18:14:52,452:py.warnings:WARNING: /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 16.91 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# <xarray.Dataset> Size: 243kB
# Dimensions:                    (time: 15205)
# Coordinates:
#   * time                       (time) datetime64[ns] 122kB 2022-01-31T21:00:0...
#     latitude                   float32 4B -42.88
#     longitude                  float32 4B 147.3
# Data variables:
#     surface_global_irradiance  (time) float64 122kB 294.6 328.0 ... nan nan

# %%
ds = ds.sortby('time')

# %%
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import pandas as pd

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(16,10))
ax = ax.flatten()
seasons = [
    # ('2016','2017'),
    # ('2017','2018'),
    # ('2018','2019'),
    # ('2019','2020'),
    # ('2020','2021'),
    # ('2021','2022'),
    ('2022','2023'),
    ('2023','2024'),
    ('2024','2025'),
]

for season in seasons:
    start = season[0]
    end = season[1]
    
    data = ds.sel(time=slice(f'{start}-12', f'{end}-02')).surface_global_irradiance
    data_mean = data.rolling(time=100, min_periods=1).mean(skipna=True)

    common_time = [
        pd.Timestamp(year=1999 if t.month == 12 else 2000, month=t.month, day=t.day,
                     hour=t.hour, minute=t.minute)
        for t in pd.to_datetime(data.time.values)
    ]
    
    if end == '2025':
        color='red'
        alpha=1
    else:
        color='grey'
        alpha=0.5

    ax[0].plot(common_time, data, color=color, alpha=alpha, label=end)
    ax[1].plot(data_mean, color=color, alpha=alpha, label=end)
    ax[0].legend()
