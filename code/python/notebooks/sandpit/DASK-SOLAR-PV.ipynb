# %%
from dask.distributed import Client, as_completed
from datetime import datetime, timedelta
from compute_solar import solar_workflow_DASK
import climtas.nci

# %%
client = Client(
    n_workers=10,
    threads_per_worker=1
)
client
# Out:
# <Client: 'tcp://127.0.0.1:45525' processes=10 threads=10, memory=95.00 GiB>

# %%
if __name__ == '__main__':
    start_date = '1-1-2018'
    end_date = '5-1-2018'
    
    start_dt = datetime.strptime(start_date, "%d-%m-%Y")
    end_dt = datetime.strptime(end_date, "%d-%m-%Y")
    
    # Generate a list of dates
    date_range = [start_dt + timedelta(days=i) for i in range((end_dt - start_dt).days + 1)]
    
    futures = {}
    region = 'V'
    
    # Loop over the dates
    for date in date_range: 
        date_s = date.strftime('%Y/%m/%d')
        future = client.submit(solar_workflow_DASK, date_s, region) 
        futures[future] = f"The job for {date}"
    
    # Iterate through each result as they are completed
    for future in as_completed(futures):
        _ = future.result()  # Raises if the function failed
    
        # Remove reference to free up memory
        del futures[future]
# Out:
# 2025-04-08 09:58:30,008:compute_solar:INFO: reading data for 2018/01/05
# 2025-04-08 09:58:30,010:compute_solar:INFO: getting region shape for: V
# 2025-04-08 09:58:30,015:compute_solar:INFO: reading data for 2018/01/02
# 2025-04-08 09:58:30,015:compute_solar:INFO: reading data for 2018/01/04
# 2025-04-08 09:58:30,017:compute_solar:INFO: getting region shape for: V
# 2025-04-08 09:58:30,017:compute_solar:INFO: getting region shape for: V
# 2025-04-08 09:58:30,098:compute_solar:INFO: reading data for 2018/01/03
# 2025-04-08 09:58:30,100:compute_solar:INFO: getting region shape for: V
# 2025-04-08 09:58:30,137:compute_solar:INFO: reading data for 2018/01/01
# 2025-04-08 09:58:30,139:compute_solar:INFO: getting region shape for: V
# 2025-04-08 09:58:30,233:compute_solar:INFO: chunking data with lat/lon size of: 50
# 2025-04-08 09:58:30,234:compute_solar:INFO: Loading 103 files
# 2025-04-08 09:58:30,240:compute_solar:INFO: chunking data with lat/lon size of: 50
# 2025-04-08 09:58:30,242:compute_solar:INFO: Loading 103 files
# 2025-04-08 09:58:30,260:compute_solar:INFO: chunking data with lat/lon size of: 50
# 2025-04-08 09:58:30,262:compute_solar:INFO: Loading 103 files
# 2025-04-08 09:58:30,302:compute_solar:INFO: chunking data with lat/lon size of: 50
# 2025-04-08 09:58:30,304:compute_solar:INFO: Loading 103 files
# 2025-04-08 09:58:30,356:compute_solar:INFO: chunking data with lat/lon size of: 50
# 2025-04-08 09:58:30,357:compute_solar:INFO: Loading 103 files
# 2025-04-08 09:58:41,900:compute_solar:INFO: apply mask for region: V
# INFO:compute_solar:apply mask for region: V
# 2025-04-08 09:58:41,917:compute_solar:INFO: reading dataset variables
# INFO:compute_solar:reading dataset variables
# 2025-04-08 09:58:41,966:compute_solar:INFO: apply mask for region: V
# INFO:compute_solar:apply mask for region: V
# 2025-04-08 09:58:41,981:compute_solar:INFO: apply mask for region: V
# INFO:compute_solar:apply mask for region: V
# 2025-04-08 09:58:41,986:compute_solar:INFO: reading dataset variables
# INFO:compute_solar:reading dataset variables
# 2025-04-08 09:58:42,006:compute_solar:INFO: reading dataset variables
# INFO:compute_solar:reading dataset variables
# 2025-04-08 09:58:42,086:compute_solar:INFO: apply mask for region: V
# INFO:compute_solar:apply mask for region: V
# 2025-04-08 09:58:42,105:compute_solar:INFO: reading dataset variables
# INFO:compute_solar:reading dataset variables
# 2025-04-08 09:58:42,166:compute_solar:INFO: apply mask for region: V
# INFO:compute_solar:apply mask for region: V
# 2025-04-08 09:58:42,193:compute_solar:INFO: reading dataset variables
# INFO:compute_solar:reading dataset variables
# 2025-04-08 09:59:13,994:compute_solar:INFO: mask applied to irradiance
# INFO:compute_solar:mask applied to irradiance
# 2025-04-08 09:59:14,092:compute_solar:INFO: mask applied to irradiance
# INFO:compute_solar:mask applied to irradiance
# 2025-04-08 09:59:14,163:compute_solar:INFO: mask applied to irradiance
# INFO:compute_solar:mask applied to irradiance
# 2025-04-08 09:59:14,169:compute_solar:INFO: mask applied to irradiance
# INFO:compute_solar:mask applied to irradiance
# 2025-04-08 09:59:14,384:compute_solar:INFO: running pvlib functions
# INFO:compute_solar:running pvlib functions
# 2025-04-08 09:59:14,439:compute_solar:INFO: running pvlib functions
# INFO:compute_solar:running pvlib functions
# 2025-04-08 09:59:14,511:compute_solar:INFO: running pvlib functions
# INFO:compute_solar:running pvlib functions
# 2025-04-08 09:59:14,765:compute_solar:INFO: running pvlib functions
# INFO:compute_solar:running pvlib functions
# 2025-04-08 09:59:15,171:compute_solar:INFO: mask applied to irradiance
# INFO:compute_solar:mask applied to irradiance
# 2025-04-08 09:59:15,540:compute_solar:INFO: running pvlib functions
# INFO:compute_solar:running pvlib functions
# 2025-04-08 09:59:23,467:py.warnings:WARNING: /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 56.02 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
#
# WARNING:py.warnings:/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 56.02 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
#
# 2025-04-08 09:59:23,536:py.warnings:WARNING: /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 56.82 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
#
# WARNING:py.warnings:/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 56.82 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
#
# 2025-04-08 09:59:23,681:py.warnings:WARNING: /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 56.78 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
#
# WARNING:py.warnings:/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 56.78 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
#
# 2025-04-08 09:59:24,536:py.warnings:WARNING: /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 56.21 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
#
# WARNING:py.warnings:/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 56.21 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
#
# 2025-04-08 09:59:31,953:py.warnings:WARNING: /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 56.73 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
#
# WARNING:py.warnings:/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 56.73 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
#
# 2025-04-08 09:59:34,674:py.warnings:WARNING: /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 56.20 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
#
# WARNING:py.warnings:/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 56.20 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
#
# 2025-04-08 09:59:34,831:py.warnings:WARNING: /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 56.77 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
#
# WARNING:py.warnings:/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 56.77 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
#
# 2025-04-08 10:03:10,589:compute_solar:INFO: Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/V/2018/01//V_timeseries_2018-01-04.nc
# INFO:compute_solar:Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/V/2018/01//V_timeseries_2018-01-04.nc
# 2025-04-08 10:03:10,620:compute_solar:INFO: Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/V/2018/01//V_timeseries_2018-01-03.nc
# INFO:compute_solar:Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/V/2018/01//V_timeseries_2018-01-03.nc
# 2025-04-08 10:03:10,631:compute_solar:INFO: Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/V/2018/01//V_timeseries_2018-01-02.nc
# INFO:compute_solar:Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/V/2018/01//V_timeseries_2018-01-02.nc
# 2025-04-08 10:03:10,713:compute_solar:INFO: Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/V/2018/01//V_timeseries_2018-01-01.nc
# INFO:compute_solar:Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/V/2018/01//V_timeseries_2018-01-01.nc
# 2025-04-08 10:03:10,733:compute_solar:INFO: END OF SOLAR_WORKFLOW_DASK
# INFO:compute_solar:END OF SOLAR_WORKFLOW_DASK
# 2025-04-08 10:03:10,736:compute_solar:INFO: END OF SOLAR_WORKFLOW_DASK
# INFO:compute_solar:END OF SOLAR_WORKFLOW_DASK
# 2025-04-08 10:03:10,764:compute_solar:INFO: END OF SOLAR_WORKFLOW_DASK
# INFO:compute_solar:END OF SOLAR_WORKFLOW_DASK
# 2025-04-08 10:03:10,910:compute_solar:INFO: END OF SOLAR_WORKFLOW_DASK
# INFO:compute_solar:END OF SOLAR_WORKFLOW_DASK
# 2025-04-08 10:03:11,763:compute_solar:INFO: Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/V/2018/01//V_timeseries_2018-01-05.nc
# INFO:compute_solar:Writing data to /g/data/er8/users/cd3022/solar_drought/REZ_tilting/V/2018/01//V_timeseries_2018-01-05.nc
# 2025-04-08 10:03:11,904:compute_solar:INFO: END OF SOLAR_WORKFLOW_DASK
# INFO:compute_solar:END OF SOLAR_WORKFLOW_DASK
